# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
  
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'term', 'originated', 'term', 'as', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(
            softmax_weights, softmax_biases, embed, train_labels, num_sampled, vocabulary_size
        )
    )

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.446145
# Nearest to known: vargas, lima, hurdles, injera, axiom, batsmen, pruitt, rush,
# Nearest to his: organizers, tight, reconciled, maryam, arsenide, atahualpa, figurehead, redrawn,
# Nearest to an: vesicle, tag, apolitical, shot, inen, litovsk, tux, crates,
# Nearest to will: asser, manu, boundaries, nazareth, resemblances, shimizu, rocket, filk,
# Nearest to from: descending, impairments, phraseology, muni, garuda, grossly, belisarius, interconnects,
# Nearest to had: dan, blackmailed, clothes, parva, burns, mod, molecule, monstrous,
# Nearest to use: molecules, saul, cheat, illuminate, ips, clayton, boomers, puts,
# Nearest to if: nauru, decadent, pointe, fiore, aircraft, pictorial, amphetamine, ironclad,
# Nearest to used: strewn, maintained, gorges, allegiance, defensively, furnishings, store, theophoric,
# Nearest to were: melchizedek, montr, korps, conqueror, hf, motorist, fertilizers, receptacle,
# Nearest to can: hammett, mets, mike, poetics, favre, cay, negatives, waka,
# Nearest to was: sunflower, habsburg, specialised, hempstead, alen, kain, cycle, klerk,
# Nearest to has: abeken, aye, ot, ther, harsh, inhaling, ketone, naismith,
# Nearest to when: gout, parody, rukh, l, interconnects, solicitor, byline, boswell,
# Nearest to at: taipa, multiplication, valleys, shiite, jagged, happiness, aymara, liable,
# Nearest to on: save, merges, weaken, evading, winding, ther, adaption, essentially,
# Average loss at step 2000: 4.356125
# Average loss at step 4000: 3.856511
# Average loss at step 6000: 3.788741
# Average loss at step 8000: 3.685668
# Average loss at step 10000: 3.617302
# Nearest to known: vargas, neanderthal, grt, such, nemours, andamanese, pollinator, axiom,
# Nearest to his: their, s, the, her, its, alexandria, reconquista, superintendent,
# Nearest to an: the, rebellions, shot, chydenius, unites, progressively, alexandros, minestrone,
# Nearest to will: would, can, boundaries, may, shimizu, asser, romanization, arguably,
# Nearest to from: in, by, including, hissing, of, velar, at, tent,
# Nearest to had: has, have, was, burns, robustus, ville, macphail, macarthur,
# Nearest to use: saul, puts, cheat, molecules, shou, illuminate, verbally, dks,
# Nearest to if: decadent, pictorial, nauru, amphetamine, chuvash, mancala, should, aircraft,
# Nearest to used: strewn, hon, sinful, diminished, cessna, surfacing, gorges, transporters,
# Nearest to were: are, was, argentinean, topaz, carter, have, hund, be,
# Nearest to can: may, would, will, should, could, drink, presuppose, unprepared,
# Nearest to was: is, had, were, by, has, are, gaulle, karmal,
# Nearest to has: had, is, have, was, solstice, ensured, infirmities, aye,
# Nearest to when: algirdas, gout, mechanized, canossa, grammatik, laver, ss, temperate,
# Nearest to at: on, of, in, dakuten, including, vhdl, taipa, second,
# Nearest to on: at, in, porsche, of, caverns, sergei, mcbride, by,
# Average loss at step 12000: 3.606094
# Average loss at step 14000: 3.573143
# Average loss at step 16000: 3.408337
# Average loss at step 18000: 3.459432
# Average loss at step 20000: 3.541845
# Nearest to known: such, seen, grt, vargas, neanderthal, viewed, axiom, kohanim,
# Nearest to his: their, its, her, the, eurocard, ndnis, jointly, many,
# Nearest to an: bishkek, latinus, rebellions, suburbs, fusing, discontinuous, seuss, recover,
# Nearest to will: would, can, may, should, could, to, must, orpheus,
# Nearest to from: in, into, at, for, and, after, on, with,
# Nearest to had: has, have, was, were, heroic, macarthur, received, palomino,
# Nearest to use: saul, puts, illuminate, molecules, trough, esteemed, ajaccio, verbally,
# Nearest to if: so, should, is, wallpaper, but, wasn, mancala, toward,
# Nearest to used: diminished, strewn, sinful, hon, regarded, realtime, cessna, splendid,
# Nearest to were: are, was, had, have, be, clothing, is, been,
# Nearest to can: may, would, will, could, should, must, cannot, might,
# Nearest to was: is, were, had, has, became, although, be, are,
# Nearest to has: had, have, was, is, solstice, having, kidnap, dhekelia,
# Nearest to when: covering, canossa, algirdas, but, gave, cools, mechanized, temperate,
# Nearest to at: in, on, of, and, dakuten, from, under, with,
# Nearest to on: in, at, upon, xof, ipkf, from, under, renegade,
# Average loss at step 22000: 3.501592
# Average loss at step 24000: 3.489733
# Average loss at step 26000: 3.477287
# Average loss at step 28000: 3.479829
# Average loss at step 30000: 3.505624
# Nearest to known: such, seen, described, used, viewed, well, grt, vargas,
# Nearest to his: her, their, its, s, the, my, our, ndnis,
# Nearest to an: soliah, progressively, rebellions, fusing, emigr, bishkek, alexandros, another,
# Nearest to will: would, can, may, should, could, must, cannot, to,
# Nearest to from: into, in, and, after, including, of, by, oneida,
# Nearest to had: has, have, was, were, having, when, is, since,
# Nearest to use: saul, puts, verbally, molecules, hue, span, shou, illuminate,
# Nearest to if: when, so, should, is, though, within, although, wallpaper,
# Nearest to used: known, found, regarded, sinful, viewed, diminished, polg, published,
# Nearest to were: are, was, had, have, by, is, gaius, been,
# Nearest to can: may, would, will, could, must, should, cannot, might,
# Nearest to was: is, had, were, has, became, been, by, montagu,
# Nearest to has: had, have, is, was, having, pagerank, dhekelia, advisers,
# Nearest to when: if, until, but, while, after, had, where, gave,
# Nearest to at: in, on, tribulations, dakuten, under, majorana, cheshire, isma,
# Nearest to on: upon, in, at, during, dakuten, for, regarding, about,
# Average loss at step 32000: 3.503370
# Average loss at step 34000: 3.493605
# Average loss at step 36000: 3.452744
# Average loss at step 38000: 3.302622
# Average loss at step 40000: 3.430620
# Nearest to known: such, used, described, seen, viewed, regarded, well, grt,
# Nearest to his: their, her, its, the, s, my, flyers, jointly,
# Nearest to an: fusing, addressee, oui, emigr, coronations, apolitical, dtd, soliah,
# Nearest to will: would, can, may, should, could, must, to, cannot,
# Nearest to from: into, in, macedonians, through, including, fretless, motels, while,
# Nearest to had: has, have, was, having, were, would, been, since,
# Nearest to use: saul, span, hue, verbally, suprema, puts, twinning, needed,
# Nearest to if: when, is, mancala, so, though, becomes, where, within,
# Nearest to used: found, regarded, known, viewed, described, considered, sinful, referred,
# Nearest to were: are, have, was, been, be, had, although, these,
# Nearest to can: may, will, would, could, must, should, cannot, might,
# Nearest to was: is, has, became, had, were, be, been, montagu,
# Nearest to has: had, have, was, is, advisers, having, received, arousal,
# Nearest to when: if, while, by, before, hibernation, where, but, after,
# Nearest to at: on, during, until, yad, tribulations, across, under, mousa,
# Nearest to on: upon, at, during, evading, in, carnivore, metrication, longest,
# Average loss at step 42000: 3.436786
# Average loss at step 44000: 3.457995
# Average loss at step 46000: 3.441277
# Average loss at step 48000: 3.349136
# Average loss at step 50000: 3.384091
# Nearest to known: used, such, described, regarded, seen, viewed, called, well,
# Nearest to his: her, their, its, my, our, flyers, whose, the,
# Nearest to an: fusing, bishkek, oui, soliah, the, dtd, apolitical, server,
# Nearest to will: would, can, should, could, may, must, might, cannot,
# Nearest to from: into, in, through, since, during, after, across, garuda,
# Nearest to had: has, have, was, were, having, since, rightarrow, selectively,
# Nearest to use: span, twinning, hue, saul, columns, rest, change, extraordinary,
# Nearest to if: when, though, where, although, mancala, so, while, becomes,
# Nearest to used: known, regarded, found, viewed, written, referred, described, considered,
# Nearest to were: are, was, have, had, be, been, although, receive,
# Nearest to can: may, would, will, could, must, should, cannot, might,
# Nearest to was: is, has, were, became, had, be, arousal, ud,
# Nearest to has: had, have, was, is, advisers, having, contains, dhekelia,
# Nearest to when: if, while, after, but, before, during, until, although,
# Nearest to at: under, across, during, on, incumbent, supercomputing, dollar, ebne,
# Nearest to on: upon, in, for, under, at, ipkf, xof, dakuten,
# Average loss at step 52000: 3.436457
# Average loss at step 54000: 3.421760
# Average loss at step 56000: 3.439086
# Average loss at step 58000: 3.399916
# Average loss at step 60000: 3.391542
# Nearest to known: used, such, regarded, described, seen, viewed, called, considered,
# Nearest to his: her, their, its, my, our, the, your, raisin,
# Nearest to an: oui, fusing, soliah, minestrone, rebellions, bishkek, apolitical, athabasca,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to from: into, through, in, since, including, macedonians, fretless, after,
# Nearest to had: has, have, was, having, received, were, showed, became,
# Nearest to use: hue, strands, twinning, study, span, saul, terms, datatype,
# Nearest to if: when, where, though, although, before, mancala, since, becomes,
# Nearest to used: known, found, regarded, written, described, designed, viewed, considered,
# Nearest to were: are, was, be, have, although, had, been, niigata,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to was: is, became, had, has, were, be, although, montagu,
# Nearest to has: had, have, was, is, contains, dhekelia, having, solstice,
# Nearest to when: if, while, although, after, before, during, though, with,
# Nearest to at: across, in, maghreb, cheshire, depicting, eurocents, advaita, during,
# Nearest to on: upon, through, regarding, nx, in, premises, about, kaolinite,
# Average loss at step 62000: 3.238036
# Average loss at step 64000: 3.258794
# Average loss at step 66000: 3.399795
# Average loss at step 68000: 3.391030
# Average loss at step 70000: 3.358616
# Nearest to known: used, such, regarded, described, viewed, seen, called, defined,
# Nearest to his: her, their, its, my, our, your, eurocard, expertise,
# Nearest to an: bishkek, fusing, minestrone, apolitical, dtd, soliah, mushroom, academies,
# Nearest to will: would, may, can, could, must, should, might, cannot,
# Nearest to from: into, through, by, while, macedonians, fretless, motels, in,
# Nearest to had: has, have, was, having, were, been, never, showed,
# Nearest to use: hue, study, strands, terms, dewar, twinning, convince, return,
# Nearest to if: when, though, before, although, mancala, where, because, while,
# Nearest to used: known, found, regarded, written, available, designed, viewed, seen,
# Nearest to were: are, was, have, be, had, although, while, been,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to was: is, were, has, became, had, becomes, been, when,
# Nearest to has: had, have, is, was, contains, having, dhekelia, since,
# Nearest to when: if, while, although, before, though, where, however, because,
# Nearest to at: during, on, across, tribulations, rooks, maghreb, supercomputing, near,
# Nearest to on: upon, through, in, regarding, at, sync, within, under,
# Average loss at step 72000: 3.372656
# Average loss at step 74000: 3.352016
# Average loss at step 76000: 3.310277
# Average loss at step 78000: 3.350425
# Average loss at step 80000: 3.378619
# Nearest to known: used, regarded, viewed, seen, described, such, important, defined,
# Nearest to his: her, their, its, my, our, your, the, ndnis,
# Nearest to an: bishkek, fusing, rebellions, oui, mushroom, seuss, academies, latinus,
# Nearest to will: would, can, must, may, could, should, might, cannot,
# Nearest to from: into, through, macedonians, across, wreck, oneida, motels, and,
# Nearest to had: have, has, were, was, having, never, became, been,
# Nearest to use: study, stinging, strands, terms, aux, saul, twinning, hue,
# Nearest to if: when, though, before, then, although, mancala, since, because,
# Nearest to used: known, found, written, referred, available, given, defined, designed,
# Nearest to were: are, was, had, although, those, be, have, became,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to was: is, became, were, had, has, been, be, becomes,
# Nearest to has: had, have, is, was, having, contains, since, streetcar,
# Nearest to when: if, before, although, after, though, while, during, where,
# Nearest to at: in, tribulations, on, across, during, dakuten, norepinephrine, connexion,
# Nearest to on: upon, in, through, regarding, at, under, during, lutz,
# Average loss at step 82000: 3.402430
# Average loss at step 84000: 3.408608
# Average loss at step 86000: 3.390865
# Average loss at step 88000: 3.349075
# Average loss at step 90000: 3.363894
# Nearest to known: used, regarded, viewed, described, such, seen, possible, called,
# Nearest to his: her, their, its, my, your, our, the, s,
# Nearest to an: bishkek, soliah, rebellions, mushroom, fusing, giuliani, oui, latinus,
# Nearest to will: would, could, must, should, can, may, might, cannot,
# Nearest to from: through, into, while, during, between, fretless, across, until,
# Nearest to had: has, have, was, were, having, never, been, gradually,
# Nearest to use: terms, stinging, study, sextans, twinning, change, because, addition,
# Nearest to if: when, though, where, before, since, although, because, after,
# Nearest to used: known, found, written, seen, designed, given, viewed, regarded,
# Nearest to were: are, had, was, have, although, while, those, these,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to was: is, had, became, were, has, been, karmal, laredo,
# Nearest to has: had, have, is, having, was, contains, requires, dhekelia,
# Nearest to when: if, before, while, after, although, during, until, where,
# Nearest to at: in, on, during, under, aas, around, near, yad,
# Nearest to on: upon, under, regarding, at, vy, porsche, carnivore, characterizes,
# Average loss at step 92000: 3.396867
# Average loss at step 94000: 3.254061
# Average loss at step 96000: 3.357260
# Average loss at step 98000: 3.244740
# Average loss at step 100000: 3.355064
# Nearest to known: such, regarded, possible, viewed, described, used, seen, important,
# Nearest to his: her, their, my, our, your, its, the, s,
# Nearest to an: bishkek, soliah, apolitical, another, romani, fusing, latinus, dtd,
# Nearest to will: would, could, can, must, should, may, might, cannot,
# Nearest to from: into, motels, through, in, across, fugues, symbolizes, garuda,
# Nearest to had: has, have, were, having, was, showed, been, since,
# Nearest to use: terms, stinging, sextans, appropriately, result, annuals, change, strands,
# Nearest to if: when, though, where, before, although, because, after, while,
# Nearest to used: found, given, written, designed, held, defined, known, seen,
# Nearest to were: are, was, have, had, these, although, those, be,
# Nearest to can: could, may, will, must, would, should, cannot, might,
# Nearest to was: is, became, were, has, had, becomes, been, although,
# Nearest to has: had, have, is, was, contains, having, dhekelia, since,
# Nearest to when: if, while, although, after, before, where, during, though,
# Nearest to at: on, during, across, in, near, nadia, soir, yad,
# Nearest to on: upon, in, at, regarding, within, under, xof, against,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# The model proposed is such simple in getting contexts so we can just swap labels and inputs to get CBOW analogy

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        # WOW SUCH CBOW
        batch_labels, batch_data = generate_batch(batch_size, num_skips, skip_window)
        batch_data = batch_data.reshape((batch_size,))
        batch_labels = batch_labels.reshape((batch_size, 1))
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.832501
# Nearest to known: ordering, cortez, lopes, patria, pounding, rabinowitz, pohnpei, manure,
# Nearest to his: verbal, asn, syndicalism, stepson, unequivocal, urges, euston, structure,
# Nearest to an: deities, parmenides, chechen, henchmen, worshiped, expiration, rips, defections,
# Nearest to will: solenoid, gums, pentameter, outcrops, navarrese, mcguire, disability, confirmation,
# Nearest to from: dawning, humanoid, maoists, hydrodynamic, pars, transgendered, foreknowledge, multiprocessor,
# Nearest to had: solubility, feudal, prodigious, aragorn, kimball, jamil, sideways, missions,
# Nearest to use: gags, socony, cafes, irreplaceable, satem, keitai, textbook, geopolitical,
# Nearest to if: mordor, secession, novel, chant, nuggets, modules, drusus, hu,
# Nearest to used: aunts, fatalism, beatmatching, leonhard, zoological, undeniably, swinging, dispositions,
# Nearest to were: olympic, venues, lampoon, kat, sheba, vanadium, stabilizers, trustees,
# Nearest to can: insulate, swollen, absence, supple, inquest, undernet, sparsely, baudelaire,
# Nearest to was: nursia, alchemical, arturo, propagates, device, assr, absence, competition,
# Nearest to has: lover, newbie, obnoxious, tory, synchronous, mores, zara, piper,
# Nearest to when: syme, gangster, belle, equation, tableland, menezes, clavier, xaf,
# Nearest to at: canetti, erfurt, marta, minefields, marquis, polarized, faerie, enclosure,
# Nearest to on: freyr, cradle, absolutely, aspect, tetrahedron, tapered, originator, rarefied,
# Average loss at step 2000: 4.364467
# Average loss at step 4000: 3.880101
# Average loss at step 6000: 3.802784
# Average loss at step 8000: 3.756497
# Average loss at step 10000: 3.627279
# Nearest to known: cortez, skirmishes, trigonometric, well, uncertainties, himself, zee, agate,
# Nearest to his: the, their, its, s, cummins, enslavement, slavic, malenkov,
# Nearest to an: prevent, deities, mithraea, galactic, expiration, undifferentiated, transforms, palatinate,
# Nearest to will: must, confirmation, could, can, solenoid, would, owsley, gums,
# Nearest to from: in, and, on, ungodly, powerpuff, illnesses, advocated, centralized,
# Nearest to had: have, has, do, feudal, was, ess, solubility, were,
# Nearest to use: petrovich, melinda, end, socony, chaker, gags, apps, cafes,
# Nearest to if: novel, secession, modules, nuggets, when, kgf, atlantis, catalonia,
# Nearest to used: recount, beatmatching, leonhard, chokes, handhelds, religionfacts, undeniably, octopussy,
# Nearest to were: are, was, and, intents, is, by, have, inductance,
# Nearest to can: would, may, could, must, sanctioning, will, confirmation, dworkin,
# Nearest to was: is, were, has, by, are, arturo, be, had,
# Nearest to has: have, is, had, was, ampersand, piracy, fuller, behaviour,
# Nearest to when: syme, barren, cannot, if, cyp, concentrating, poseidon, rennes,
# Nearest to at: on, in, for, souvenir, is, canetti, mons, after,
# Nearest to on: in, at, from, and, first, of, tattooing, ltv,
# Average loss at step 12000: 3.584263
# Average loss at step 14000: 3.612686
# Average loss at step 16000: 3.579870
# Average loss at step 18000: 3.567729
# Average loss at step 20000: 3.545338
# Nearest to known: cortez, such, seen, well, used, skirmishes, trigonometric, uncertainties,
# Nearest to his: their, her, its, the, s, malenkov, dreadful, reindeer,
# Nearest to an: deities, mithraea, krona, prevent, expanding, expiration, undetected, asymptotically,
# Nearest to will: would, can, must, could, may, might, confirmation, to,
# Nearest to from: into, yevgeny, in, by, through, at, between, centralized,
# Nearest to had: has, have, was, ampersand, were, symbolise, intents, hesychastic,
# Nearest to use: end, petrovich, melinda, chaker, socony, knots, tones, gags,
# Nearest to if: when, novel, secession, sutton, where, however, catalonia, distracted,
# Nearest to used: seen, known, groton, middlesbrough, recount, considered, done, beatmatching,
# Nearest to were: are, have, was, intents, presenting, by, been, had,
# Nearest to can: would, may, will, could, must, cannot, to, should,
# Nearest to was: is, had, by, has, were, arturo, been, when,
# Nearest to has: had, have, is, was, kuo, ampersand, absorptive, taino,
# Nearest to when: if, after, was, cannot, poseidon, cyp, until, devoid,
# Nearest to at: after, on, in, from, for, during, unu, pows,
# Nearest to on: in, at, endosymbiotic, tattooing, under, against, piston, concluding,
# Average loss at step 22000: 3.530126
# Average loss at step 24000: 3.439588
# Average loss at step 26000: 3.418625
# Average loss at step 28000: 3.478133
# Average loss at step 30000: 3.409733
# Nearest to known: well, used, such, seen, described, cortez, skirmishes, uncertainties,
# Nearest to his: her, their, the, its, s, my, sacking, menagerie,
# Nearest to an: deities, the, expiration, undetected, galactic, mithraea, undifferentiated, sadd,
# Nearest to will: would, can, must, may, could, should, cannot, might,
# Nearest to from: through, into, centralized, in, ungodly, between, under, powerpuff,
# Nearest to had: has, have, was, ampersand, intents, having, piracy, were,
# Nearest to use: end, petrovich, melinda, chaker, knots, beating, calista, map,
# Nearest to if: when, where, novel, though, however, sutton, macross, does,
# Nearest to used: considered, available, seen, known, written, referred, recount, theron,
# Nearest to were: are, was, intents, have, had, been, be, cyclops,
# Nearest to can: may, will, would, could, must, cannot, should, might,
# Nearest to was: is, had, has, were, when, became, by, arturo,
# Nearest to has: had, have, was, is, ampersand, harrier, situational, electrotechnical,
# Nearest to when: if, was, after, although, with, because, since, until,
# Nearest to at: in, on, during, pettigrew, after, avicenna, unu, jaian,
# Nearest to on: at, in, upon, tragically, tattooing, near, during, under,
# Average loss at step 32000: 3.414911
# Average loss at step 34000: 3.441086
# Average loss at step 36000: 3.363216
# Average loss at step 38000: 3.494191
# Average loss at step 40000: 3.440395
# Nearest to known: used, such, seen, described, well, uncertainties, trigonometric, extraction,
# Nearest to his: their, her, its, the, my, s, breakage, dimona,
# Nearest to an: deities, expiration, bolshevist, carving, mojave, another, bremen, the,
# Nearest to will: would, can, must, could, may, should, might, cannot,
# Nearest to from: through, into, under, in, centralized, ungodly, after, during,
# Nearest to had: has, have, was, were, intents, having, never, began,
# Nearest to use: end, melinda, petrovich, langston, practice, themed, knots, sense,
# Nearest to if: when, though, where, did, does, municipality, macross, although,
# Nearest to used: known, seen, available, considered, referred, influenced, recount, introduced,
# Nearest to were: are, was, have, had, intents, been, be, laughing,
# Nearest to can: may, would, will, could, must, should, cannot, might,
# Nearest to was: is, were, had, has, adonis, been, became, when,
# Nearest to has: had, have, was, is, since, intents, microscopy, ampersand,
# Nearest to when: if, after, before, although, because, with, during, was,
# Nearest to at: in, on, during, after, resurrect, hofstadter, souvenir, pettigrew,
# Nearest to on: upon, at, piston, typographic, against, tetrahedron, through, under,
# Average loss at step 42000: 3.426204
# Average loss at step 44000: 3.279150
# Average loss at step 46000: 3.410124
# Average loss at step 48000: 3.425016
# Average loss at step 50000: 3.434673
# Nearest to known: used, such, seen, uncertainties, described, well, possible, regarded,
# Nearest to his: their, her, its, the, my, spo, s, prophets,
# Nearest to an: deities, expiration, zondervan, chechen, islam, tools, strengthened, mojave,
# Nearest to will: would, must, can, may, could, should, might, cannot,
# Nearest to from: through, into, in, under, centralized, across, between, illnesses,
# Nearest to had: has, have, was, intents, having, were, began, ampersand,
# Nearest to use: end, melinda, petrovich, practice, langston, sense, themed, exist,
# Nearest to if: when, where, though, although, because, then, municipality, will,
# Nearest to used: known, available, considered, seen, written, affected, referred, done,
# Nearest to were: are, was, have, had, those, when, intents, is,
# Nearest to can: may, would, could, will, must, cannot, might, should,
# Nearest to was: is, had, were, has, became, when, be, seems,
# Nearest to has: had, have, is, was, since, lande, cladistic, intents,
# Nearest to when: if, before, after, although, though, while, was, where,
# Nearest to at: in, on, during, after, avicenna, cannonball, near, insensible,
# Nearest to on: upon, in, at, during, under, about, through, against,
# Average loss at step 52000: 3.457021
# Average loss at step 54000: 3.430633
# Average loss at step 56000: 3.405003
# Average loss at step 58000: 3.282027
# Average loss at step 60000: 3.383377
# Nearest to known: used, such, uncertainties, seen, opposed, regarded, described, possible,
# Nearest to his: her, their, its, the, my, your, our, s,
# Nearest to an: deities, another, expiration, undifferentiated, strengthened, mojave, fgm, zondervan,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to from: through, into, across, ungodly, during, in, under, including,
# Nearest to had: has, have, having, was, intents, were, never, ampersand,
# Nearest to use: end, practice, petrovich, melinda, langston, sense, gags, measure,
# Nearest to if: when, though, where, although, will, consider, encompasses, carcinogenic,
# Nearest to used: available, known, seen, considered, written, done, referred, introduced,
# Nearest to were: are, was, have, although, those, been, had, include,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to was: is, became, were, had, has, when, been, be,
# Nearest to has: had, have, is, was, includes, since, absorptive, solicitors,
# Nearest to when: if, after, although, before, where, was, though, however,
# Nearest to at: in, during, pettigrew, near, cannonball, after, from, narita,
# Nearest to on: upon, in, against, through, tetrahedron, during, under, typographic,
# Average loss at step 62000: 3.439285
# Average loss at step 64000: 3.358217
# Average loss at step 66000: 3.344211
# Average loss at step 68000: 3.385558
# Average loss at step 70000: 3.368224
# Nearest to known: used, such, opposed, seen, described, extraction, regarded, minesweeper,
# Nearest to his: her, their, its, my, your, the, s, our,
# Nearest to an: expiration, another, deities, mojave, undetected, zondervan, undifferentiated, astbury,
# Nearest to will: would, can, could, must, may, should, cannot, might,
# Nearest to from: through, across, during, into, in, including, under, ungodly,
# Nearest to had: has, have, having, intents, was, never, were, since,
# Nearest to use: gags, langston, measure, end, knots, melinda, define, petrovich,
# Nearest to if: when, though, where, although, before, is, does, because,
# Nearest to used: available, known, seen, considered, responsible, done, affected, written,
# Nearest to were: are, was, those, have, although, be, including, been,
# Nearest to can: will, would, may, could, must, should, cannot, might,
# Nearest to was: is, were, became, be, had, has, been, arturo,
# Nearest to has: had, have, is, was, since, electrotechnical, includes, having,
# Nearest to when: if, after, although, where, while, before, though, because,
# Nearest to at: in, on, during, near, pettigrew, unu, ideologically, whois,
# Nearest to on: upon, through, in, at, within, around, near, under,
# Average loss at step 72000: 3.404617
# Average loss at step 74000: 3.388687
# Average loss at step 76000: 3.348726
# Average loss at step 78000: 3.234677
# Average loss at step 80000: 3.376652
# Nearest to known: used, seen, possible, described, regarded, opposed, such, called,
# Nearest to his: her, their, its, your, my, the, spo, our,
# Nearest to an: deities, chechen, undetected, zondervan, mojave, fgm, palatinate, rnsson,
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to from: across, into, through, ungodly, during, under, toward, centralized,
# Nearest to had: has, have, having, intents, were, was, continued, never,
# Nearest to use: because, end, most, apply, voting, practice, results, define,
# Nearest to if: when, where, is, though, for, because, x, immaterial,
# Nearest to used: available, done, required, known, seen, designed, found, responsible,
# Nearest to were: are, was, had, although, have, those, been, including,
# Nearest to can: may, will, would, could, should, must, cannot, might,
# Nearest to was: is, were, became, had, has, becomes, been, be,
# Nearest to has: had, have, is, was, implies, solicitors, since, includes,
# Nearest to when: if, after, while, although, where, though, because, before,
# Nearest to at: during, in, near, on, pettigrew, cannonball, ahab, dialog,
# Nearest to on: upon, through, at, tattooing, in, against, typographic, concluding,
# Average loss at step 82000: 3.295121
# Average loss at step 84000: 3.339567
# Average loss at step 86000: 3.346122
# Average loss at step 88000: 3.322429
# Average loss at step 90000: 3.243412
# Nearest to known: such, used, seen, opposed, described, regarded, possible, referred,
# Nearest to his: her, their, its, my, your, the, our, spo,
# Nearest to an: undetected, deities, mojave, zondervan, mizrahi, patience, another, chechen,
# Nearest to will: would, could, must, can, should, may, cannot, might,
# Nearest to from: through, across, into, in, ungodly, during, after, on,
# Nearest to had: has, have, was, having, intents, were, since, continued,
# Nearest to use: list, exist, apply, langston, reigning, hanssen, need, formulas,
# Nearest to if: when, though, where, because, before, although, does, carcinogenic,
# Nearest to used: available, done, known, seen, required, responsible, introduced, found,
# Nearest to were: are, was, had, include, have, although, been, being,
# Nearest to can: could, would, may, will, must, should, cannot, might,
# Nearest to was: is, had, were, became, been, has, be, although,
# Nearest to has: had, have, is, was, since, tithe, solicitors, having,
# Nearest to when: if, after, where, although, while, before, though, by,
# Nearest to at: during, in, near, pettigrew, club, hopwood, on, after,
# Nearest to on: upon, in, tattooing, concluding, about, from, at, around,
# Average loss at step 92000: 2.737923
# Average loss at step 94000: 3.097341
# Average loss at step 96000: 3.067821
# Average loss at step 98000: 3.222603
# Average loss at step 100000: 3.280317
# Nearest to known: used, such, seen, regarded, opposed, described, cited, possible,
# Nearest to his: her, their, its, your, my, our, s, the,
# Nearest to an: another, zondervan, deities, mizrahi, mojave, undetected, astbury, boats,
# Nearest to will: would, could, must, can, should, might, cannot, may,
# Nearest to from: across, through, into, universitet, amazement, in, foreknowledge, ungodly,
# Nearest to had: has, have, having, was, never, intents, since, were,
# Nearest to use: apply, gags, need, amount, list, define, harass, timeline,
# Nearest to if: when, though, where, before, because, doves, tell, moribund,
# Nearest to used: done, available, known, designed, seen, required, introduced, intended,
# Nearest to were: are, was, those, have, although, include, be, while,
# Nearest to can: could, would, must, will, may, should, cannot, might,
# Nearest to was: is, became, had, be, has, were, although, been,
# Nearest to has: had, have, is, was, although, tithe, since, cladistic,
# Nearest to when: if, where, although, though, after, while, before, because,
# Nearest to at: during, near, pettigrew, in, around, on, cannonball, ideologically,
# Nearest to on: upon, in, against, within, tattooing, through, about, at,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
